# %%
import os
import time
import random
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as tv
from torchvision.utils import make_grid
from sklearn.model_selection import train_test_split
from PIL import Image
import logging
import matplotlib.pyplot as plt
import copy
import pandas as pd
# %matplotlib inline

# %%
mylogs = logging.getLogger()
mylogs.setLevel(logging.INFO)
# Logging to file
file = logging.FileHandler("training.log", mode='w')
file.setLevel(logging.INFO)
fileformat = logging.Formatter("%(asctime)s:%(levelname)s:%(message)s",datefmt="%H:%M:%S")
file.setFormatter(fileformat)
mylogs.addHandler(file)
# Logging to console
stream = logging.StreamHandler()
stream.setLevel(logging.INFO)
mylogs.addHandler(stream)

# %% [markdown]
# # Paths and parameters

# %%
train_img_dir= r"E:/lungs_segmentation/train/images/"
train_mask_dir =  r"E:/lungs_segmentation/train/masks/"
test_img_dir = r"E:/lungs_segmentation/test/images/"
test_mask_dir = r"E:/lungs_segmentation/test/masks/"
model_name = 'Unet'
project_name = "CT_lung_segmentation"
resize_size = (256, 256)

# %% [markdown]
# # Creating list of images and masks

# %%
def create_img_list(img_folder):
    img_list = []
    for (dirpath, dirnames, filenames) in os.walk(img_folder):
        img_list += [os.path.join(dirpath, file) for file in filenames]
    return img_list

# %%
train_img_list = create_img_list(train_img_dir)
test_img_list = create_img_list(test_img_dir)

if train_mask_dir:
    train_mask_img_list = create_img_list(train_mask_dir)
if test_mask_dir:
    test_mask_img_list = create_img_list(test_mask_dir)

# %%
def make_img_mask_pairs(img_list, mask_list):
    img_path_names =  {os.path.basename(n):n for n in img_list}
    mask_path_names =  {os.path.basename(n):n for n in mask_list}
    img_mask_pairs = {}
    for name, path in img_path_names.items():
        if name in mask_path_names.keys():
            img_mask_pairs[path] = mask_path_names[name]
    return(img_mask_pairs)

# %%
test_img_mask_pairs = make_img_mask_pairs(test_img_list,test_mask_img_list)

# %%
train_img_mask_pairs = make_img_mask_pairs(train_img_list,train_mask_img_list)

# %%
def train_val_split(img_dic, split_ratio):
    val_dic = {}
    train_dic = {}
    for i in range(int(len(img_dic)*split_ratio)):
        random_entry = random.choice(list(img_dic.keys()))
        val_dic[random_entry] = img_dic[random_entry]    
    for key in img_dic.keys():
        if key not in val_dic.keys():
            train_dic[key] = img_dic[key]
    return(train_dic, val_dic)

# %%
train_img_mask_pairs, val_img_mask_pairs = train_val_split(train_img_mask_pairs, 0.2)

# %% [markdown]
# # Image Loading functions

# %%
def get_img_transform():
    return tv.Compose([
        tv.ToTensor(),
        tv.Normalize((0), (1)),
        
    ])
def get_mask_transform():
    return tv.Compose([
        tv.ToTensor(),
    ])
transforms = (get_img_transform(),get_mask_transform())

# %%
class loadDataset(Dataset):
    def __init__(self,img_mask_pairs_dic, transforms):
        super().__init__()
        self.imgs = list(img_mask_pairs_dic.keys())
        self.masks = list(img_mask_pairs_dic.values())
        self.img_transform = transforms[0]
        self.mask_transform = transforms[1]
        
    def __getitem__(self, idx):
        image_path = self.imgs[idx]
        mask_path = self.masks[idx]
      ### Reading, converting and normalizing image
            ### Reading, converting and normalizing image
        img = Image.open(image_path)
        img = img.resize((resize_size[0], resize_size[1]))
            ### Doing the same for mask
        mask = Image.open(mask_path)
        mask = mask.resize((resize_size[0], resize_size[1]))
            ### Apply Transforms on image
        img = self.img_transform(img)
            
            # creating mask tensor as a label
        mask  = self.mask_transform(mask)
        return img, mask

    def __len__(self):
        return len(self.imgs)

# %%
train_dataset = loadDataset(train_img_mask_pairs, transforms)
val_dataset = loadDataset(val_img_mask_pairs, transforms)
test_dataset = loadDataset(test_img_mask_pairs, transforms)

# %%
train_data_loader = DataLoader(
    dataset = train_dataset,
    num_workers = 0,
    batch_size = 4,
    shuffle = True
)
val_data_loader = DataLoader(
    dataset = val_dataset,
    num_workers = 0,
    batch_size = 1,
    shuffle = True
)
test_data_loader = DataLoader(
    dataset = test_dataset,
    num_workers = 0,
    batch_size = 1,
    shuffle = True
)

# %%
  def dataset_preview(train_data_loader):
    for image, mask in train_data_loader:
        masked_img = image + mask.int().float() 
        imgs = (image, masked_img)
        # https://stackoverflow.com/questions/41793931/plotting-images-side-by-side-using-matplotlib by YellowPillow
        n_row = 1
        n_col = 2
        _, axs = plt.subplots(n_row, n_col, figsize=(18, 18))
        axs = axs.flatten()
        titles = [' Image', 'Image with mask']
        for title, img, ax in zip(titles, imgs, axs):
            ax.imshow(make_grid(img, 4).permute(1,2,0))
            ax.set_title(title)
        plt.show()
        break
        
dataset_preview(train_data_loader)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
dataset_preview(test_data_loader)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # Functions for training

# %%
# https://github.com/milesial/Pytorch-UNet/blob/master/unet/unet_model.py
n_channels = 1
n_classes = 1
from UNet import UNet
model = UNet(n_channels, n_classes)

# %%
#from https://www.kaggle.com/bigironsphere/loss-function-library-keras-pytorch
class DiceBCELoss(nn.Module):
    # Return Dice and Dice loss
    def __init__(self, weight=None, size_average=True):
        super(DiceBCELoss, self).__init__()

    def forward(self, inputs, targets, smooth=1):
        #comment out if your model contains a sigmoid or equivalent activation layer
        inputs = torch.sigmoid(inputs)       
        
        #flatten label and prediction tensors
        inputs = inputs.view(-1)
        targets = targets.view(-1)
        
        intersection = (inputs * targets).sum()
        dice_coefficient =  (2. * intersection + smooth) / (torch.sum(targets) + torch.sum(inputs) + smooth)
        
        dice_loss = 1 - (2.*intersection + smooth)/(inputs.sum() + targets.sum() + smooth)  
        BCE = F.binary_cross_entropy(inputs, targets, reduction='mean')
        Dice_BCE = BCE + dice_loss
        
        return Dice_BCE, dice_coefficient

# %%
class Optimizer:
    def __init__(self, model):
        self.optimizer_dict = {}
        self.optimizer_dict['optimizer'] = torch.optim.Adam(model.parameters(), lr = 0.0001)
        self.optimizer_dict['lr_scheduler'] = torch.optim.lr_scheduler.StepLR(self.optimizer_dict['optimizer'], step_size = 5, gamma = 0.5)
        self.optimizer_dict['criterion'] = DiceBCELoss(nn.Module)

    def return_state_dict(self):
        return self.optimizer_dict['optimizer'].state_dict()

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
optimizerA = Optimizer(model)

# %%
mylogs.info("Model: " + model_name )
# Loading model to device
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
mylogs.info(f"Device is: {str(device)}")
model.to(device)
optimizerA = Optimizer(model)
# Out:
# Model: Unet
# Model: Unet
# Device is: cuda
# Device is: cuda

# %%
def train_one_epoch(data_loader, optimizer_obj, phase):
    ## global to local
    optimizer = optimizer_obj.optimizer_dict['optimizer']
    criterion = optimizer_obj.optimizer_dict['criterion']
    lr_scheduler = optimizer_obj.optimizer_dict['criterion'] 
    ### Local Parameters
    epoch_loss = []
    epoch_dice = []
    start_time = time.time()
    
    ###Iterating over data loader
    for images, labels in data_loader:
        #Loading images and labels to device
        images = images.to(device)
        labels = labels.to(device)
        #Reseting Gradients
        optimizer.zero_grad()
        #Forward
        preds = model(images)
        #Calculating Loss
        _loss, dice_coefficient = criterion(preds, labels)
        loss = _loss.item()
        epoch_loss.append(float(loss))
        epoch_dice.append(float(dice_coefficient))
        #Backward if train phase
        if phase == "train":
            _loss.backward()
            optimizer.step()
    ###Overall Epoch Results
    end_time = time.time()
    total_time = int(end_time - start_time)/60
    ###Dice coefficient and Loss
    epoch_loss = np.mean(epoch_loss)
    epoch_dice = np.mean(epoch_dice)
    ###Storing results to logs
    return epoch_loss, epoch_dice, total_time

# %%
def report_in_progress(phase, epoch, loss, dice, _time):
       #Print epoch details
        mylogs.info(f'{"Training" if phase == False else "Validation"} Epoch {epoch}: | Loss: {loss:.5f} | Dice: {dice:.3f} | Time: {(round(_time, 4))}')

# %%
def train_model(model, optimizer_obj, max_n_epochs, early_stop_epoch_thresh = 15):
    start_time = time.time()
    # initializing  training stats
    train_logs =  {"loss" : [], "dice coefficient" : [], "time" : []}
    val_logs = {"loss" : [], "dice coefficient" : [], "time" : []} 
    mylogs.info("Training started")
    best_model = model
    best_epoch = 1
    best_val_dice = 0
    bad_dice_epoch = 0
    current_epoch = 0
    best_train_logs = {}
    best_val_logs = {}
    best_model_optimizer_state_dict = optimizer_obj.return_state_dict()
    for epoch in range(1, max_n_epochs + 1):
        if bad_dice_epoch < early_stop_epoch_thresh:
            current_epoch = epoch 
            ###Training
            train_loss, train_dice, train_time = train_one_epoch(train_data_loader, optimizer_obj, "train")
            #Print train Epoch Details      
            report_in_progress(0, epoch, train_loss, train_dice, train_time)
            #Adding stats for the epoch
            train_logs["loss"].append(train_loss)
            train_logs["dice coefficient"].append(train_dice)
            train_logs["time"].append(train_time)
            ###Validation
            val_loss, val_dice, val_time = train_one_epoch(val_data_loader, optimizer_obj, "validation")
            #Print Val Epoch  Details
            report_in_progress(1, epoch, val_loss, val_dice, val_time)
            #adding stats on the epoch
            val_logs["loss"].append(val_loss)
            val_logs["dice coefficient"].append(val_dice)
            val_logs["time"].append(val_time)
            # Early stop processing
            if val_dice > best_val_dice:
                best_val_dice = val_dice
                best_model = copy.deepcopy(model)
                bad_dice_epoch = 0
                best_train_logs = train_logs
                best_val_logs = val_logs
                best_epoch = epoch 
            else:
                bad_dice_epoch +=1
        else:
            mylogs.info(f"Early stop, best dice coefficient: {best_val_dice}%")
            break
    end_time = time.time()
    total_time = end_time - start_time
    mylogs.info(f"Total time : {int(total_time/60)}")
    # packing training data into a dictionary
    training_stats = {}
    training_stats['train logs'] = train_logs
    training_stats['validation logs'] = val_logs
    training_stats['best train logs'] = best_train_logs
    training_stats['best validation logs'] = best_val_logs
    training_stats['best validation dice'] = best_val_dice
    training_stats['best epoch'] = best_epoch
    training_stats['current epoch'] = current_epoch 
    
    return best_model, best_model_optimizer_state_dict, training_stats

# %%
# Training de novo
n_of_epochs = 120
model, model_optimizer_state_dict,  training_stats = train_model(model, optimizerA, n_of_epochs)
# Out:
# Training started
# Training started
# Training Epoch 1: | Loss: 0.83305 | Dice: 0.473 | Time: 2.0833
# Training Epoch 1: | Loss: 0.83305 | Dice: 0.473 | Time: 2.0833
# Validation Epoch 1: | Loss: 0.92021 | Dice: 0.436 | Time: 0.1833
# Validation Epoch 1: | Loss: 0.92021 | Dice: 0.436 | Time: 0.1833
# Training Epoch 2: | Loss: 0.50509 | Dice: 0.635 | Time: 2.1167
# Training Epoch 2: | Loss: 0.50509 | Dice: 0.635 | Time: 2.1167
# Validation Epoch 2: | Loss: 0.81457 | Dice: 0.500 | Time: 0.1833
# Validation Epoch 2: | Loss: 0.81457 | Dice: 0.500 | Time: 0.1833
# Training Epoch 3: | Loss: 0.33202 | Dice: 0.752 | Time: 2.1167
# Training Epoch 3: | Loss: 0.33202 | Dice: 0.752 | Time: 2.1167
# Validation Epoch 3: | Loss: 0.58376 | Dice: 0.586 | Time: 0.1667
# Validation Epoch 3: | Loss: 0.58376 | Dice: 0.586 | Time: 0.1667
# Training Epoch 4: | Loss: 0.21579 | Dice: 0.835 | Time: 2.1
# Training Epoch 4: | Loss: 0.21579 | Dice: 0.835 | Time: 2.1
# Validation Epoch 4: | Loss: 0.50343 | Dice: 0.618 | Time: 0.1667
# Validation Epoch 4: | Loss: 0.50343 | Dice: 0.618 | Time: 0.1667
# Training Epoch 5: | Loss: 0.17885 | Dice: 0.867 | Time: 2.1167
# Training Epoch 5: | Loss: 0.17885 | Dice: 0.867 | Time: 2.1167
# Validation Epoch 5: | Loss: 0.45584 | Dice: 0.635 | Time: 0.1667
# Validation Epoch 5: | Loss: 0.45584 | Dice: 0.635 | Time: 0.1667
# Training Epoch 6: | Loss: 0.15474 | Dice: 0.886 | Time: 2.1333
# Training Epoch 6: | Loss: 0.15474 | Dice: 0.886 | Time: 2.1333
# Validation Epoch 6: | Loss: 0.41669 | Dice: 0.655 | Time: 0.1833
# Validation Epoch 6: | Loss: 0.41669 | Dice: 0.655 | Time: 0.1833
# Training Epoch 7: | Loss: 0.10782 | Dice: 0.921 | Time: 2.15
# Training Epoch 7: | Loss: 0.10782 | Dice: 0.921 | Time: 2.15
# Validation Epoch 7: | Loss: 0.40966 | Dice: 0.660 | Time: 0.1833
# Validation Epoch 7: | Loss: 0.40966 | Dice: 0.660 | Time: 0.1833
# Training Epoch 8: | Loss: 0.10778 | Dice: 0.920 | Time: 2.2167
# Training Epoch 8: | Loss: 0.10778 | Dice: 0.920 | Time: 2.2167
# Validation Epoch 8: | Loss: 0.38967 | Dice: 0.674 | Time: 0.1833
# Validation Epoch 8: | Loss: 0.38967 | Dice: 0.674 | Time: 0.1833
# Training Epoch 9: | Loss: 0.10376 | Dice: 0.926 | Time: 2.15
# Training Epoch 9: | Loss: 0.10376 | Dice: 0.926 | Time: 2.15
# Validation Epoch 9: | Loss: 0.43060 | Dice: 0.662 | Time: 0.1833
# Validation Epoch 9: | Loss: 0.43060 | Dice: 0.662 | Time: 0.1833
# Training Epoch 10: | Loss: 0.09730 | Dice: 0.930 | Time: 2.1333
# Training Epoch 10: | Loss: 0.09730 | Dice: 0.930 | Time: 2.1333
# Validation Epoch 10: | Loss: 0.35920 | Dice: 0.677 | Time: 0.1667
# Validation Epoch 10: | Loss: 0.35920 | Dice: 0.677 | Time: 0.1667
# Training Epoch 11: | Loss: 0.08543 | Dice: 0.939 | Time: 2.2833
# Training Epoch 11: | Loss: 0.08543 | Dice: 0.939 | Time: 2.2833
# Validation Epoch 11: | Loss: 0.38323 | Dice: 0.691 | Time: 0.2833
# Validation Epoch 11: | Loss: 0.38323 | Dice: 0.691 | Time: 0.2833
# Training Epoch 12: | Loss: 0.07706 | Dice: 0.946 | Time: 2.3
# Training Epoch 12: | Loss: 0.07706 | Dice: 0.946 | Time: 2.3
# Validation Epoch 12: | Loss: 0.36603 | Dice: 0.694 | Time: 0.1667
# Validation Epoch 12: | Loss: 0.36603 | Dice: 0.694 | Time: 0.1667
# Training Epoch 13: | Loss: 0.07690 | Dice: 0.946 | Time: 2.4333
# Training Epoch 13: | Loss: 0.07690 | Dice: 0.946 | Time: 2.4333
# Validation Epoch 13: | Loss: 0.37657 | Dice: 0.688 | Time: 0.2
# Validation Epoch 13: | Loss: 0.37657 | Dice: 0.688 | Time: 0.2
# Training Epoch 14: | Loss: 0.07012 | Dice: 0.952 | Time: 2.4833
# Training Epoch 14: | Loss: 0.07012 | Dice: 0.952 | Time: 2.4833
# Validation Epoch 14: | Loss: 0.37083 | Dice: 0.700 | Time: 0.1667
# Validation Epoch 14: | Loss: 0.37083 | Dice: 0.700 | Time: 0.1667
# Training Epoch 15: | Loss: 0.06004 | Dice: 0.958 | Time: 2.5167
# Training Epoch 15: | Loss: 0.06004 | Dice: 0.958 | Time: 2.5167
# Validation Epoch 15: | Loss: 0.35325 | Dice: 0.706 | Time: 0.1833
# Validation Epoch 15: | Loss: 0.35325 | Dice: 0.706 | Time: 0.1833
# Training Epoch 16: | Loss: 0.07359 | Dice: 0.950 | Time: 2.5
# Training Epoch 16: | Loss: 0.07359 | Dice: 0.950 | Time: 2.5
# Validation Epoch 16: | Loss: 0.34381 | Dice: 0.699 | Time: 0.2167
# Validation Epoch 16: | Loss: 0.34381 | Dice: 0.699 | Time: 0.2167
# Training Epoch 17: | Loss: 0.06623 | Dice: 0.953 | Time: 2.5833
# Training Epoch 17: | Loss: 0.06623 | Dice: 0.953 | Time: 2.5833
# Validation Epoch 17: | Loss: 0.33724 | Dice: 0.711 | Time: 0.1667
# Validation Epoch 17: | Loss: 0.33724 | Dice: 0.711 | Time: 0.1667
# Training Epoch 18: | Loss: 0.05274 | Dice: 0.963 | Time: 2.55
# Training Epoch 18: | Loss: 0.05274 | Dice: 0.963 | Time: 2.55
# Validation Epoch 18: | Loss: 0.33760 | Dice: 0.711 | Time: 0.1667
# Validation Epoch 18: | Loss: 0.33760 | Dice: 0.711 | Time: 0.1667
# Training Epoch 19: | Loss: 0.04600 | Dice: 0.968 | Time: 2.5167
# Training Epoch 19: | Loss: 0.04600 | Dice: 0.968 | Time: 2.5167
# Validation Epoch 19: | Loss: 0.32834 | Dice: 0.716 | Time: 0.3
# Validation Epoch 19: | Loss: 0.32834 | Dice: 0.716 | Time: 0.3
# Training Epoch 20: | Loss: 0.04718 | Dice: 0.966 | Time: 2.4667
# Training Epoch 20: | Loss: 0.04718 | Dice: 0.966 | Time: 2.4667
# Validation Epoch 20: | Loss: 0.30496 | Dice: 0.718 | Time: 0.1667
# Validation Epoch 20: | Loss: 0.30496 | Dice: 0.718 | Time: 0.1667
# Training Epoch 21: | Loss: 0.05754 | Dice: 0.961 | Time: 2.55
# Training Epoch 21: | Loss: 0.05754 | Dice: 0.961 | Time: 2.55
# Validation Epoch 21: | Loss: 0.48168 | Dice: 0.700 | Time: 0.3
# Validation Epoch 21: | Loss: 0.48168 | Dice: 0.700 | Time: 0.3
# Training Epoch 22: | Loss: 0.05142 | Dice: 0.965 | Time: 2.45
# Training Epoch 22: | Loss: 0.05142 | Dice: 0.965 | Time: 2.45
# Validation Epoch 22: | Loss: 0.30637 | Dice: 0.716 | Time: 0.1833
# Validation Epoch 22: | Loss: 0.30637 | Dice: 0.716 | Time: 0.1833
# Training Epoch 23: | Loss: 0.04357 | Dice: 0.969 | Time: 2.5833
# Training Epoch 23: | Loss: 0.04357 | Dice: 0.969 | Time: 2.5833
# Validation Epoch 23: | Loss: 0.30276 | Dice: 0.715 | Time: 0.2
# Validation Epoch 23: | Loss: 0.30276 | Dice: 0.715 | Time: 0.2
# Training Epoch 24: | Loss: 0.04556 | Dice: 0.966 | Time: 2.55
# Training Epoch 24: | Loss: 0.04556 | Dice: 0.966 | Time: 2.55
# Validation Epoch 24: | Loss: 0.30051 | Dice: 0.719 | Time: 0.1667
# Validation Epoch 24: | Loss: 0.30051 | Dice: 0.719 | Time: 0.1667
# Training Epoch 25: | Loss: 0.05771 | Dice: 0.962 | Time: 2.5833
# Training Epoch 25: | Loss: 0.05771 | Dice: 0.962 | Time: 2.5833
# Validation Epoch 25: | Loss: 0.30933 | Dice: 0.715 | Time: 0.3
# Validation Epoch 25: | Loss: 0.30933 | Dice: 0.715 | Time: 0.3
# Training Epoch 26: | Loss: 0.04470 | Dice: 0.970 | Time: 2.5
# Training Epoch 26: | Loss: 0.04470 | Dice: 0.970 | Time: 2.5
# Validation Epoch 26: | Loss: 0.29581 | Dice: 0.724 | Time: 0.1667
# Validation Epoch 26: | Loss: 0.29581 | Dice: 0.724 | Time: 0.1667
# Training Epoch 27: | Loss: 0.03932 | Dice: 0.972 | Time: 2.5833
# Training Epoch 27: | Loss: 0.03932 | Dice: 0.972 | Time: 2.5833
# Validation Epoch 27: | Loss: 0.30320 | Dice: 0.722 | Time: 0.1833
# Validation Epoch 27: | Loss: 0.30320 | Dice: 0.722 | Time: 0.1833
# Training Epoch 28: | Loss: 0.04084 | Dice: 0.971 | Time: 2.6
# Training Epoch 28: | Loss: 0.04084 | Dice: 0.971 | Time: 2.6
# Validation Epoch 28: | Loss: 0.37295 | Dice: 0.685 | Time: 0.1667
# Validation Epoch 28: | Loss: 0.37295 | Dice: 0.685 | Time: 0.1667
# Training Epoch 29: | Loss: 0.05192 | Dice: 0.964 | Time: 2.6
# Training Epoch 29: | Loss: 0.05192 | Dice: 0.964 | Time: 2.6
# Validation Epoch 29: | Loss: 0.32518 | Dice: 0.706 | Time: 0.2
# Validation Epoch 29: | Loss: 0.32518 | Dice: 0.706 | Time: 0.2
# Training Epoch 30: | Loss: 0.03722 | Dice: 0.975 | Time: 2.5333
# Training Epoch 30: | Loss: 0.03722 | Dice: 0.975 | Time: 2.5333
# Validation Epoch 30: | Loss: 0.31625 | Dice: 0.726 | Time: 0.3
# Validation Epoch 30: | Loss: 0.31625 | Dice: 0.726 | Time: 0.3
# Training Epoch 31: | Loss: 0.03552 | Dice: 0.975 | Time: 2.45
# Training Epoch 31: | Loss: 0.03552 | Dice: 0.975 | Time: 2.45
# Validation Epoch 31: | Loss: 0.34561 | Dice: 0.721 | Time: 0.3167
# Validation Epoch 31: | Loss: 0.34561 | Dice: 0.721 | Time: 0.3167
# Training Epoch 32: | Loss: 0.03613 | Dice: 0.974 | Time: 2.4667
# Training Epoch 32: | Loss: 0.03613 | Dice: 0.974 | Time: 2.4667
# Validation Epoch 32: | Loss: 0.31701 | Dice: 0.735 | Time: 0.1833
# Validation Epoch 32: | Loss: 0.31701 | Dice: 0.735 | Time: 0.1833
# Training Epoch 33: | Loss: 0.05312 | Dice: 0.963 | Time: 2.5833
# Training Epoch 33: | Loss: 0.05312 | Dice: 0.963 | Time: 2.5833
# Validation Epoch 33: | Loss: 0.35812 | Dice: 0.714 | Time: 0.3
# Validation Epoch 33: | Loss: 0.35812 | Dice: 0.714 | Time: 0.3
# Training Epoch 34: | Loss: 0.04244 | Dice: 0.969 | Time: 2.45
# Training Epoch 34: | Loss: 0.04244 | Dice: 0.969 | Time: 2.45
# Validation Epoch 34: | Loss: 0.30643 | Dice: 0.735 | Time: 0.3167
# Validation Epoch 34: | Loss: 0.30643 | Dice: 0.735 | Time: 0.3167
# Training Epoch 35: | Loss: 0.04274 | Dice: 0.969 | Time: 2.45
# Training Epoch 35: | Loss: 0.04274 | Dice: 0.969 | Time: 2.45
# Validation Epoch 35: | Loss: 0.30222 | Dice: 0.739 | Time: 0.1667
# Validation Epoch 35: | Loss: 0.30222 | Dice: 0.739 | Time: 0.1667
# Training Epoch 36: | Loss: 0.03107 | Dice: 0.978 | Time: 2.65
# Training Epoch 36: | Loss: 0.03107 | Dice: 0.978 | Time: 2.65
# Validation Epoch 36: | Loss: 0.29569 | Dice: 0.741 | Time: 0.1667
# Validation Epoch 36: | Loss: 0.29569 | Dice: 0.741 | Time: 0.1667
# Training Epoch 37: | Loss: 0.02782 | Dice: 0.982 | Time: 2.5833
# Training Epoch 37: | Loss: 0.02782 | Dice: 0.982 | Time: 2.5833
# Validation Epoch 37: | Loss: 0.31481 | Dice: 0.740 | Time: 0.1833
# Validation Epoch 37: | Loss: 0.31481 | Dice: 0.740 | Time: 0.1833
# Training Epoch 38: | Loss: 0.02937 | Dice: 0.980 | Time: 2.6
# Training Epoch 38: | Loss: 0.02937 | Dice: 0.980 | Time: 2.6
# Validation Epoch 38: | Loss: 0.30511 | Dice: 0.743 | Time: 0.1667
# Validation Epoch 38: | Loss: 0.30511 | Dice: 0.743 | Time: 0.1667
# Training Epoch 39: | Loss: 0.04877 | Dice: 0.967 | Time: 2.65
# Training Epoch 39: | Loss: 0.04877 | Dice: 0.967 | Time: 2.65
# Validation Epoch 39: | Loss: 0.29887 | Dice: 0.728 | Time: 0.2
# Validation Epoch 39: | Loss: 0.29887 | Dice: 0.728 | Time: 0.2
# Training Epoch 40: | Loss: 0.04104 | Dice: 0.971 | Time: 2.5667
# Training Epoch 40: | Loss: 0.04104 | Dice: 0.971 | Time: 2.5667
# Validation Epoch 40: | Loss: 0.27685 | Dice: 0.744 | Time: 0.1833
# Validation Epoch 40: | Loss: 0.27685 | Dice: 0.744 | Time: 0.1833
# Training Epoch 41: | Loss: 0.02969 | Dice: 0.980 | Time: 2.5667
# Training Epoch 41: | Loss: 0.02969 | Dice: 0.980 | Time: 2.5667
# Validation Epoch 41: | Loss: 0.27756 | Dice: 0.749 | Time: 0.1833
# Validation Epoch 41: | Loss: 0.27756 | Dice: 0.749 | Time: 0.1833
# Training Epoch 42: | Loss: 0.03460 | Dice: 0.974 | Time: 2.5833
# Training Epoch 42: | Loss: 0.03460 | Dice: 0.974 | Time: 2.5833
# Validation Epoch 42: | Loss: 0.25803 | Dice: 0.759 | Time: 0.3
# Validation Epoch 42: | Loss: 0.25803 | Dice: 0.759 | Time: 0.3
# Training Epoch 43: | Loss: 0.03469 | Dice: 0.974 | Time: 2.5
# Training Epoch 43: | Loss: 0.03469 | Dice: 0.974 | Time: 2.5
# Validation Epoch 43: | Loss: 0.27112 | Dice: 0.754 | Time: 0.1667
# Validation Epoch 43: | Loss: 0.27112 | Dice: 0.754 | Time: 0.1667
# Training Epoch 44: | Loss: 0.02584 | Dice: 0.983 | Time: 2.6167
# Training Epoch 44: | Loss: 0.02584 | Dice: 0.983 | Time: 2.6167
# Validation Epoch 44: | Loss: 0.27638 | Dice: 0.758 | Time: 0.1833
# Validation Epoch 44: | Loss: 0.27638 | Dice: 0.758 | Time: 0.1833
# Training Epoch 45: | Loss: 0.03269 | Dice: 0.977 | Time: 2.6167
# Training Epoch 45: | Loss: 0.03269 | Dice: 0.977 | Time: 2.6167
# Validation Epoch 45: | Loss: 0.25680 | Dice: 0.771 | Time: 0.2333
# Validation Epoch 45: | Loss: 0.25680 | Dice: 0.771 | Time: 0.2333
# Training Epoch 46: | Loss: 0.03160 | Dice: 0.978 | Time: 2.5667
# Training Epoch 46: | Loss: 0.03160 | Dice: 0.978 | Time: 2.5667
# Validation Epoch 46: | Loss: 0.25682 | Dice: 0.763 | Time: 0.1833
# Validation Epoch 46: | Loss: 0.25682 | Dice: 0.763 | Time: 0.1833
# Training Epoch 47: | Loss: 0.03684 | Dice: 0.974 | Time: 2.6167
# Training Epoch 47: | Loss: 0.03684 | Dice: 0.974 | Time: 2.6167
# Validation Epoch 47: | Loss: 0.25343 | Dice: 0.776 | Time: 0.1833
# Validation Epoch 47: | Loss: 0.25343 | Dice: 0.776 | Time: 0.1833
# Training Epoch 48: | Loss: 0.03358 | Dice: 0.977 | Time: 2.6167
# Training Epoch 48: | Loss: 0.03358 | Dice: 0.977 | Time: 2.6167
# Validation Epoch 48: | Loss: 0.30471 | Dice: 0.763 | Time: 0.2167
# Validation Epoch 48: | Loss: 0.30471 | Dice: 0.763 | Time: 0.2167
# Training Epoch 49: | Loss: 0.03949 | Dice: 0.973 | Time: 2.5667
# Training Epoch 49: | Loss: 0.03949 | Dice: 0.973 | Time: 2.5667
# Validation Epoch 49: | Loss: 0.24343 | Dice: 0.770 | Time: 0.1667
# Validation Epoch 49: | Loss: 0.24343 | Dice: 0.770 | Time: 0.1667
# Training Epoch 50: | Loss: 0.02700 | Dice: 0.982 | Time: 2.5833
# Training Epoch 50: | Loss: 0.02700 | Dice: 0.982 | Time: 2.5833
# Validation Epoch 50: | Loss: 0.23084 | Dice: 0.782 | Time: 0.25
# Validation Epoch 50: | Loss: 0.23084 | Dice: 0.782 | Time: 0.25
# Training Epoch 51: | Loss: 0.03489 | Dice: 0.975 | Time: 2.5
# Training Epoch 51: | Loss: 0.03489 | Dice: 0.975 | Time: 2.5
# Validation Epoch 51: | Loss: 0.21880 | Dice: 0.793 | Time: 0.3
# Validation Epoch 51: | Loss: 0.21880 | Dice: 0.793 | Time: 0.3
# Training Epoch 52: | Loss: 0.03017 | Dice: 0.978 | Time: 2.4833
# Training Epoch 52: | Loss: 0.03017 | Dice: 0.978 | Time: 2.4833
# Validation Epoch 52: | Loss: 0.21678 | Dice: 0.793 | Time: 0.2833
# Validation Epoch 52: | Loss: 0.21678 | Dice: 0.793 | Time: 0.2833
# Training Epoch 53: | Loss: 0.02806 | Dice: 0.980 | Time: 2.4833
# Training Epoch 53: | Loss: 0.02806 | Dice: 0.980 | Time: 2.4833
# Validation Epoch 53: | Loss: 0.23342 | Dice: 0.779 | Time: 0.1833
# Validation Epoch 53: | Loss: 0.23342 | Dice: 0.779 | Time: 0.1833
# Training Epoch 54: | Loss: 0.02912 | Dice: 0.980 | Time: 2.5833
# Training Epoch 54: | Loss: 0.02912 | Dice: 0.980 | Time: 2.5833
# Validation Epoch 54: | Loss: 0.19866 | Dice: 0.812 | Time: 0.1833
# Validation Epoch 54: | Loss: 0.19866 | Dice: 0.812 | Time: 0.1833
# Training Epoch 55: | Loss: 0.03863 | Dice: 0.973 | Time: 2.6333
# Training Epoch 55: | Loss: 0.03863 | Dice: 0.973 | Time: 2.6333
# Validation Epoch 55: | Loss: 0.29667 | Dice: 0.750 | Time: 0.1667
# Validation Epoch 55: | Loss: 0.29667 | Dice: 0.750 | Time: 0.1667
# Training Epoch 56: | Loss: 0.03172 | Dice: 0.978 | Time: 2.6333
# Training Epoch 56: | Loss: 0.03172 | Dice: 0.978 | Time: 2.6333
# Validation Epoch 56: | Loss: 0.19158 | Dice: 0.819 | Time: 0.1667
# Validation Epoch 56: | Loss: 0.19158 | Dice: 0.819 | Time: 0.1667
# Training Epoch 57: | Loss: 0.02757 | Dice: 0.981 | Time: 2.5333
# Training Epoch 57: | Loss: 0.02757 | Dice: 0.981 | Time: 2.5333
# Validation Epoch 57: | Loss: 0.18971 | Dice: 0.822 | Time: 0.3
# Validation Epoch 57: | Loss: 0.18971 | Dice: 0.822 | Time: 0.3
# Training Epoch 58: | Loss: 0.03015 | Dice: 0.978 | Time: 2.4833
# Training Epoch 58: | Loss: 0.03015 | Dice: 0.978 | Time: 2.4833
# Validation Epoch 58: | Loss: 0.18653 | Dice: 0.825 | Time: 0.3
# Validation Epoch 58: | Loss: 0.18653 | Dice: 0.825 | Time: 0.3
# Training Epoch 59: | Loss: 0.03300 | Dice: 0.976 | Time: 2.5
# Training Epoch 59: | Loss: 0.03300 | Dice: 0.976 | Time: 2.5
# Validation Epoch 59: | Loss: 0.16524 | Dice: 0.847 | Time: 0.1833
# Validation Epoch 59: | Loss: 0.16524 | Dice: 0.847 | Time: 0.1833
# Training Epoch 60: | Loss: 0.02699 | Dice: 0.981 | Time: 2.6
# Training Epoch 60: | Loss: 0.02699 | Dice: 0.981 | Time: 2.6
# Validation Epoch 60: | Loss: 0.16868 | Dice: 0.843 | Time: 0.1833
# Validation Epoch 60: | Loss: 0.16868 | Dice: 0.843 | Time: 0.1833
# Training Epoch 61: | Loss: 0.04402 | Dice: 0.968 | Time: 2.6167
# Training Epoch 61: | Loss: 0.04402 | Dice: 0.968 | Time: 2.6167
# Validation Epoch 61: | Loss: 0.26854 | Dice: 0.752 | Time: 0.2833
# Validation Epoch 61: | Loss: 0.26854 | Dice: 0.752 | Time: 0.2833
# Training Epoch 62: | Loss: 0.03253 | Dice: 0.978 | Time: 2.4833
# Training Epoch 62: | Loss: 0.03253 | Dice: 0.978 | Time: 2.4833
# Validation Epoch 62: | Loss: 0.18766 | Dice: 0.826 | Time: 0.2833
# Validation Epoch 62: | Loss: 0.18766 | Dice: 0.826 | Time: 0.2833
# Training Epoch 63: | Loss: 0.03239 | Dice: 0.976 | Time: 2.5333
# Training Epoch 63: | Loss: 0.03239 | Dice: 0.976 | Time: 2.5333
# Validation Epoch 63: | Loss: 0.20992 | Dice: 0.802 | Time: 0.1667
# Validation Epoch 63: | Loss: 0.20992 | Dice: 0.802 | Time: 0.1667
# Training Epoch 64: | Loss: 0.02538 | Dice: 0.983 | Time: 2.6
# Training Epoch 64: | Loss: 0.02538 | Dice: 0.983 | Time: 2.6
# Validation Epoch 64: | Loss: 0.16377 | Dice: 0.846 | Time: 0.1833
# Validation Epoch 64: | Loss: 0.16377 | Dice: 0.846 | Time: 0.1833
# Training Epoch 65: | Loss: 0.02500 | Dice: 0.983 | Time: 2.6167
# Training Epoch 65: | Loss: 0.02500 | Dice: 0.983 | Time: 2.6167
# Validation Epoch 65: | Loss: 0.13703 | Dice: 0.873 | Time: 0.1667
# Validation Epoch 65: | Loss: 0.13703 | Dice: 0.873 | Time: 0.1667
# Training Epoch 66: | Loss: 0.03254 | Dice: 0.975 | Time: 2.5833
# Training Epoch 66: | Loss: 0.03254 | Dice: 0.975 | Time: 2.5833
# Validation Epoch 66: | Loss: 0.16703 | Dice: 0.843 | Time: 0.2333
# Validation Epoch 66: | Loss: 0.16703 | Dice: 0.843 | Time: 0.2333
# Training Epoch 67: | Loss: 0.02678 | Dice: 0.981 | Time: 2.4833
# Training Epoch 67: | Loss: 0.02678 | Dice: 0.981 | Time: 2.4833
# Validation Epoch 67: | Loss: 0.12408 | Dice: 0.887 | Time: 0.2833
# Validation Epoch 67: | Loss: 0.12408 | Dice: 0.887 | Time: 0.2833
# Training Epoch 68: | Loss: 0.02783 | Dice: 0.981 | Time: 2.4667
# Training Epoch 68: | Loss: 0.02783 | Dice: 0.981 | Time: 2.4667
# Validation Epoch 68: | Loss: 0.10619 | Dice: 0.904 | Time: 0.25
# Validation Epoch 68: | Loss: 0.10619 | Dice: 0.904 | Time: 0.25
# Training Epoch 69: | Loss: 0.02775 | Dice: 0.981 | Time: 2.6
# Training Epoch 69: | Loss: 0.02775 | Dice: 0.981 | Time: 2.6
# Validation Epoch 69: | Loss: 0.15568 | Dice: 0.854 | Time: 0.1833
# Validation Epoch 69: | Loss: 0.15568 | Dice: 0.854 | Time: 0.1833
# Training Epoch 70: | Loss: 0.03817 | Dice: 0.973 | Time: 2.5833
# Training Epoch 70: | Loss: 0.03817 | Dice: 0.973 | Time: 2.5833
# Validation Epoch 70: | Loss: 0.11167 | Dice: 0.900 | Time: 0.1667
# Validation Epoch 70: | Loss: 0.11167 | Dice: 0.900 | Time: 0.1667
# Training Epoch 71: | Loss: 0.02770 | Dice: 0.981 | Time: 2.6167
# Training Epoch 71: | Loss: 0.02770 | Dice: 0.981 | Time: 2.6167
# Validation Epoch 71: | Loss: 0.10617 | Dice: 0.904 | Time: 0.1833
# Validation Epoch 71: | Loss: 0.10617 | Dice: 0.904 | Time: 0.1833
# Training Epoch 72: | Loss: 0.02747 | Dice: 0.981 | Time: 2.6
# Training Epoch 72: | Loss: 0.02747 | Dice: 0.981 | Time: 2.6
# Validation Epoch 72: | Loss: 0.11108 | Dice: 0.900 | Time: 0.1667
# Validation Epoch 72: | Loss: 0.11108 | Dice: 0.900 | Time: 0.1667
# Training Epoch 73: | Loss: 0.02413 | Dice: 0.984 | Time: 2.55
# Training Epoch 73: | Loss: 0.02413 | Dice: 0.984 | Time: 2.55
# Validation Epoch 73: | Loss: 0.12332 | Dice: 0.893 | Time: 0.2333
# Validation Epoch 73: | Loss: 0.12332 | Dice: 0.893 | Time: 0.2333
# Training Epoch 74: | Loss: 0.02675 | Dice: 0.981 | Time: 2.5667
# Training Epoch 74: | Loss: 0.02675 | Dice: 0.981 | Time: 2.5667
# Validation Epoch 74: | Loss: 0.12619 | Dice: 0.883 | Time: 0.1833
# Validation Epoch 74: | Loss: 0.12619 | Dice: 0.883 | Time: 0.1833
# Training Epoch 75: | Loss: 0.02676 | Dice: 0.981 | Time: 2.55
# Training Epoch 75: | Loss: 0.02676 | Dice: 0.981 | Time: 2.55
# Validation Epoch 75: | Loss: 0.10391 | Dice: 0.905 | Time: 0.3333
# Validation Epoch 75: | Loss: 0.10391 | Dice: 0.905 | Time: 0.3333
# Training Epoch 76: | Loss: 0.02581 | Dice: 0.983 | Time: 2.4
# Training Epoch 76: | Loss: 0.02581 | Dice: 0.983 | Time: 2.4
# Validation Epoch 76: | Loss: 0.11889 | Dice: 0.893 | Time: 0.2833
# Validation Epoch 76: | Loss: 0.11889 | Dice: 0.893 | Time: 0.2833
# Training Epoch 77: | Loss: 0.02640 | Dice: 0.982 | Time: 2.5333
# Training Epoch 77: | Loss: 0.02640 | Dice: 0.982 | Time: 2.5333
# Validation Epoch 77: | Loss: 0.12931 | Dice: 0.884 | Time: 0.2333
# Validation Epoch 77: | Loss: 0.12931 | Dice: 0.884 | Time: 0.2333
# Training Epoch 78: | Loss: 0.03569 | Dice: 0.975 | Time: 2.55
# Training Epoch 78: | Loss: 0.03569 | Dice: 0.975 | Time: 2.55
# Validation Epoch 78: | Loss: 0.08899 | Dice: 0.921 | Time: 0.2667
# Validation Epoch 78: | Loss: 0.08899 | Dice: 0.921 | Time: 0.2667
# Training Epoch 79: | Loss: 0.02290 | Dice: 0.985 | Time: 2.5667
# Training Epoch 79: | Loss: 0.02290 | Dice: 0.985 | Time: 2.5667
# Validation Epoch 79: | Loss: 0.08359 | Dice: 0.926 | Time: 0.2167
# Validation Epoch 79: | Loss: 0.08359 | Dice: 0.926 | Time: 0.2167
# Training Epoch 80: | Loss: 0.02468 | Dice: 0.983 | Time: 2.5667
# Training Epoch 80: | Loss: 0.02468 | Dice: 0.983 | Time: 2.5667
# Validation Epoch 80: | Loss: 0.07884 | Dice: 0.931 | Time: 0.3
# Validation Epoch 80: | Loss: 0.07884 | Dice: 0.931 | Time: 0.3
# Training Epoch 81: | Loss: 0.02367 | Dice: 0.984 | Time: 2.4833
# Training Epoch 81: | Loss: 0.02367 | Dice: 0.984 | Time: 2.4833
# Validation Epoch 81: | Loss: 0.07619 | Dice: 0.934 | Time: 0.1833
# Validation Epoch 81: | Loss: 0.07619 | Dice: 0.934 | Time: 0.1833
# Training Epoch 82: | Loss: 0.03377 | Dice: 0.977 | Time: 2.6167
# Training Epoch 82: | Loss: 0.03377 | Dice: 0.977 | Time: 2.6167
# Validation Epoch 82: | Loss: 0.15872 | Dice: 0.856 | Time: 0.1833
# Validation Epoch 82: | Loss: 0.15872 | Dice: 0.856 | Time: 0.1833
# Training Epoch 83: | Loss: 0.03688 | Dice: 0.974 | Time: 2.5667
# Training Epoch 83: | Loss: 0.03688 | Dice: 0.974 | Time: 2.5667
# Validation Epoch 83: | Loss: 0.16706 | Dice: 0.849 | Time: 0.2333
# Validation Epoch 83: | Loss: 0.16706 | Dice: 0.849 | Time: 0.2333
# Training Epoch 84: | Loss: 0.02725 | Dice: 0.982 | Time: 2.5167
# Training Epoch 84: | Loss: 0.02725 | Dice: 0.982 | Time: 2.5167
# Validation Epoch 84: | Loss: 0.08068 | Dice: 0.929 | Time: 0.3333
# Validation Epoch 84: | Loss: 0.08068 | Dice: 0.929 | Time: 0.3333
# Training Epoch 85: | Loss: 0.02386 | Dice: 0.984 | Time: 2.4333
# Training Epoch 85: | Loss: 0.02386 | Dice: 0.984 | Time: 2.4333
# Validation Epoch 85: | Loss: 0.06302 | Dice: 0.947 | Time: 0.2
# Validation Epoch 85: | Loss: 0.06302 | Dice: 0.947 | Time: 0.2
# Training Epoch 86: | Loss: 0.03926 | Dice: 0.973 | Time: 2.55
# Training Epoch 86: | Loss: 0.03926 | Dice: 0.973 | Time: 2.55
# Validation Epoch 86: | Loss: 0.06750 | Dice: 0.943 | Time: 0.1667
# Validation Epoch 86: | Loss: 0.06750 | Dice: 0.943 | Time: 0.1667
# Training Epoch 87: | Loss: 0.02461 | Dice: 0.983 | Time: 2.6167
# Training Epoch 87: | Loss: 0.02461 | Dice: 0.983 | Time: 2.6167
# Validation Epoch 87: | Loss: 0.05653 | Dice: 0.953 | Time: 0.1667
# Validation Epoch 87: | Loss: 0.05653 | Dice: 0.953 | Time: 0.1667
# Training Epoch 88: | Loss: 0.02311 | Dice: 0.984 | Time: 2.55
# Training Epoch 88: | Loss: 0.02311 | Dice: 0.984 | Time: 2.55
# Validation Epoch 88: | Loss: 0.05411 | Dice: 0.955 | Time: 0.2667
# Validation Epoch 88: | Loss: 0.05411 | Dice: 0.955 | Time: 0.2667
# Training Epoch 89: | Loss: 0.02288 | Dice: 0.985 | Time: 2.5
# Training Epoch 89: | Loss: 0.02288 | Dice: 0.985 | Time: 2.5
# Validation Epoch 89: | Loss: 0.05630 | Dice: 0.953 | Time: 0.2833
# Validation Epoch 89: | Loss: 0.05630 | Dice: 0.953 | Time: 0.2833
# Training Epoch 90: | Loss: 0.02415 | Dice: 0.984 | Time: 2.55
# Training Epoch 90: | Loss: 0.02415 | Dice: 0.984 | Time: 2.55
# Validation Epoch 90: | Loss: 0.05259 | Dice: 0.956 | Time: 0.1833
# Validation Epoch 90: | Loss: 0.05259 | Dice: 0.956 | Time: 0.1833
# Training Epoch 91: | Loss: 0.02250 | Dice: 0.985 | Time: 2.6
# Training Epoch 91: | Loss: 0.02250 | Dice: 0.985 | Time: 2.6
# Validation Epoch 91: | Loss: 0.05811 | Dice: 0.952 | Time: 0.1833
# Validation Epoch 91: | Loss: 0.05811 | Dice: 0.952 | Time: 0.1833
# Training Epoch 92: | Loss: 0.02534 | Dice: 0.983 | Time: 2.5833
# Training Epoch 92: | Loss: 0.02534 | Dice: 0.983 | Time: 2.5833
# Validation Epoch 92: | Loss: 0.05744 | Dice: 0.952 | Time: 0.3333
# Validation Epoch 92: | Loss: 0.05744 | Dice: 0.952 | Time: 0.3333
# Training Epoch 93: | Loss: 0.02273 | Dice: 0.984 | Time: 2.45
# Training Epoch 93: | Loss: 0.02273 | Dice: 0.984 | Time: 2.45
# Validation Epoch 93: | Loss: 0.06651 | Dice: 0.943 | Time: 0.1833
# Validation Epoch 93: | Loss: 0.06651 | Dice: 0.943 | Time: 0.1833
# Training Epoch 94: | Loss: 0.03483 | Dice: 0.977 | Time: 2.65
# Training Epoch 94: | Loss: 0.03483 | Dice: 0.977 | Time: 2.65
# Validation Epoch 94: | Loss: 0.06046 | Dice: 0.949 | Time: 0.2
# Validation Epoch 94: | Loss: 0.06046 | Dice: 0.949 | Time: 0.2
# Training Epoch 95: | Loss: 0.02382 | Dice: 0.984 | Time: 2.5833
# Training Epoch 95: | Loss: 0.02382 | Dice: 0.984 | Time: 2.5833
# Validation Epoch 95: | Loss: 0.05108 | Dice: 0.959 | Time: 0.1667
# Validation Epoch 95: | Loss: 0.05108 | Dice: 0.959 | Time: 0.1667
# Training Epoch 96: | Loss: 0.02367 | Dice: 0.984 | Time: 2.6
# Training Epoch 96: | Loss: 0.02367 | Dice: 0.984 | Time: 2.6
# Validation Epoch 96: | Loss: 0.04950 | Dice: 0.960 | Time: 0.1833
# Validation Epoch 96: | Loss: 0.04950 | Dice: 0.960 | Time: 0.1833
# Training Epoch 97: | Loss: 0.02209 | Dice: 0.985 | Time: 2.6167
# Training Epoch 97: | Loss: 0.02209 | Dice: 0.985 | Time: 2.6167
# Validation Epoch 97: | Loss: 0.04587 | Dice: 0.963 | Time: 0.1833
# Validation Epoch 97: | Loss: 0.04587 | Dice: 0.963 | Time: 0.1833
# Training Epoch 98: | Loss: 0.02228 | Dice: 0.985 | Time: 2.6333
# Training Epoch 98: | Loss: 0.02228 | Dice: 0.985 | Time: 2.6333
# Validation Epoch 98: | Loss: 0.04597 | Dice: 0.963 | Time: 0.1833
# Validation Epoch 98: | Loss: 0.04597 | Dice: 0.963 | Time: 0.1833
# Training Epoch 99: | Loss: 0.03584 | Dice: 0.976 | Time: 2.6167
# Training Epoch 99: | Loss: 0.03584 | Dice: 0.976 | Time: 2.6167
# Validation Epoch 99: | Loss: 0.11428 | Dice: 0.901 | Time: 0.1833
# Validation Epoch 99: | Loss: 0.11428 | Dice: 0.901 | Time: 0.1833
# Training Epoch 100: | Loss: 0.03450 | Dice: 0.976 | Time: 2.65
# Training Epoch 100: | Loss: 0.03450 | Dice: 0.976 | Time: 2.65
# Validation Epoch 100: | Loss: 0.06440 | Dice: 0.947 | Time: 0.1667
# Validation Epoch 100: | Loss: 0.06440 | Dice: 0.947 | Time: 0.1667
# Training Epoch 101: | Loss: 0.02521 | Dice: 0.983 | Time: 2.6167
# Training Epoch 101: | Loss: 0.02521 | Dice: 0.983 | Time: 2.6167
# Validation Epoch 101: | Loss: 0.06031 | Dice: 0.950 | Time: 0.1667
# Validation Epoch 101: | Loss: 0.06031 | Dice: 0.950 | Time: 0.1667
# Training Epoch 102: | Loss: 0.02374 | Dice: 0.984 | Time: 2.6167
# Training Epoch 102: | Loss: 0.02374 | Dice: 0.984 | Time: 2.6167
# Validation Epoch 102: | Loss: 0.05682 | Dice: 0.953 | Time: 0.3167
# Validation Epoch 102: | Loss: 0.05682 | Dice: 0.953 | Time: 0.3167
# Training Epoch 103: | Loss: 0.02261 | Dice: 0.985 | Time: 2.5167
# Training Epoch 103: | Loss: 0.02261 | Dice: 0.985 | Time: 2.5167
# Validation Epoch 103: | Loss: 0.05500 | Dice: 0.955 | Time: 0.1833
# Validation Epoch 103: | Loss: 0.05500 | Dice: 0.955 | Time: 0.1833
# Training Epoch 104: | Loss: 0.02383 | Dice: 0.984 | Time: 2.5833
# Training Epoch 104: | Loss: 0.02383 | Dice: 0.984 | Time: 2.5833
# Validation Epoch 104: | Loss: 0.05429 | Dice: 0.955 | Time: 0.2667
# Validation Epoch 104: | Loss: 0.05429 | Dice: 0.955 | Time: 0.2667
# Training Epoch 105: | Loss: 0.02271 | Dice: 0.985 | Time: 2.5833
# Training Epoch 105: | Loss: 0.02271 | Dice: 0.985 | Time: 2.5833
# Validation Epoch 105: | Loss: 0.04986 | Dice: 0.959 | Time: 0.1833
# Validation Epoch 105: | Loss: 0.04986 | Dice: 0.959 | Time: 0.1833
# Training Epoch 106: | Loss: 0.02197 | Dice: 0.985 | Time: 2.6333
# Training Epoch 106: | Loss: 0.02197 | Dice: 0.985 | Time: 2.6333
# Validation Epoch 106: | Loss: 0.04724 | Dice: 0.962 | Time: 0.1833
# Validation Epoch 106: | Loss: 0.04724 | Dice: 0.962 | Time: 0.1833
# Training Epoch 107: | Loss: 0.02387 | Dice: 0.984 | Time: 2.6
# Training Epoch 107: | Loss: 0.02387 | Dice: 0.984 | Time: 2.6
# Validation Epoch 107: | Loss: 0.04817 | Dice: 0.962 | Time: 0.3
# Validation Epoch 107: | Loss: 0.04817 | Dice: 0.962 | Time: 0.3
# Training Epoch 108: | Loss: 0.02227 | Dice: 0.985 | Time: 2.4833
# Training Epoch 108: | Loss: 0.02227 | Dice: 0.985 | Time: 2.4833
# Validation Epoch 108: | Loss: 0.04787 | Dice: 0.962 | Time: 0.3
# Validation Epoch 108: | Loss: 0.04787 | Dice: 0.962 | Time: 0.3
# Training Epoch 109: | Loss: 0.02430 | Dice: 0.984 | Time: 2.5333
# Training Epoch 109: | Loss: 0.02430 | Dice: 0.984 | Time: 2.5333
# Validation Epoch 109: | Loss: 0.04925 | Dice: 0.960 | Time: 0.1667
# Validation Epoch 109: | Loss: 0.04925 | Dice: 0.960 | Time: 0.1667
# Training Epoch 110: | Loss: 0.02736 | Dice: 0.981 | Time: 2.6
# Training Epoch 110: | Loss: 0.02736 | Dice: 0.981 | Time: 2.6
# Validation Epoch 110: | Loss: 0.05707 | Dice: 0.953 | Time: 0.3167
# Validation Epoch 110: | Loss: 0.05707 | Dice: 0.953 | Time: 0.3167
# Training Epoch 111: | Loss: 0.02634 | Dice: 0.982 | Time: 2.5167
# Training Epoch 111: | Loss: 0.02634 | Dice: 0.982 | Time: 2.5167
# Validation Epoch 111: | Loss: 0.10016 | Dice: 0.911 | Time: 0.1833
# Validation Epoch 111: | Loss: 0.10016 | Dice: 0.911 | Time: 0.1833
# Training Epoch 112: | Loss: 0.02856 | Dice: 0.980 | Time: 2.6167
# Training Epoch 112: | Loss: 0.02856 | Dice: 0.980 | Time: 2.6167
# Validation Epoch 112: | Loss: 0.10608 | Dice: 0.906 | Time: 0.25
# Validation Epoch 112: | Loss: 0.10608 | Dice: 0.906 | Time: 0.25
# Early stop, best dice coefficient: 0.9631929618717973%
# Early stop, best dice coefficient: 0.9631929618717973%
# Total time : 307
# Total time : 307

# %% [markdown]
# # Saving and visualization

# %%
def train_vis(training_stats):

    ### Plotting Results
    train_logs = training_stats['train logs']
    val_logs = training_stats['validation logs']
    epochs = training_stats['current epoch'] + 1
    best_epoch = training_stats['best epoch'] 

#Loss
    plt.figure(figsize=(15, 6))
    
    plt.title("Loss",color='black')
    plt.plot(np.arange(1, epochs), train_logs["loss"], color = 'blue', label='Training')
    plt.plot(np.arange(1, epochs), val_logs["loss"], color = 'orange', label='Validation')
    plt.axvline(x=best_epoch,color='green')
    plt.xticks(ticks=range(1, epochs), color='black')
    plt.yticks(color='black')
    plt.xlabel("Epochs", color = 'black')
    plt.ylabel("Loss", color = 'black')
    plt.show()

# dice coefficient
    plt.figure(figsize=(15, 6))
    plt.title("Dice", color='black')
    plt.plot(np.arange(1, epochs), train_logs["dice coefficient"], color = 'blue', label='Training')
    plt.plot(np.arange(1, epochs), val_logs["dice coefficient"], color = 'orange', label='Validation')
    plt.axvline(x=best_epoch, color='green')
    plt.xticks(ticks=range(1, epochs), color='black')
    plt.yticks(color='black')
    plt.xlabel("Epochs", color = 'black')
    plt.ylabel("Accuracy", color='black')
    plt.show()

# %%
train_vis(training_stats)

# %%
# Saving the best model
def save_model(model, model_name,training_stats, parameters, img_lists):
    ''' Save model either for inference or for continuing training '''
    torch.save({'model_name': model_name,
                'parameters': (resize, n_channels, n_classes),
                'model_state_dict': model.state_dict(),
                'parameters': (resize_size, n_channels, n_classes)
                }, f'{project_name}_{model_name}_inference.pt')
        
    torch.save({'model_name': model_name,
                'model_state_dict': model.state_dict(),
                'model_stats': training_stats,
                'parameters': (resize, n_channels, n_classes),
                'img_lists': img_lists
                }, f'{project_name}_{model_name}.pt')
    mylogs.info("Model saved")

# %%
n_channels = 1
n_classes = 1
img_lists = (train_img_mask_pairs, val_img_mask_pairs, test_img_mask_pairs)
save_model(model, model_name, training_stats, (resize, n_channels,n_classes),  img_lists)
# Out:
# Model saved
# Model saved

# %%
# Testing on a random test image 
def dataset_preview(test_data_loader):
    for image, actual_mask in test_data_loader:
        image.to('cpu')
        actual_mask.to('cpu')
        model.to('cpu')
        actual_masked_img = image + actual_mask.int().float()
        prediction_mask = model(image)
        prediction_mask[prediction_mask > 0] = 1
        prediction_mask[prediction_mask <= 0] = 0
        predicted_masked_img = image + prediction_mask.int().float()

        masked_imgs = (actual_masked_img, predicted_masked_img)
        n_row = 1
        n_col = 2
        # https://stackoverflow.com/questions/41793931/plotting-images-side-by-side-using-matplotlib by YellowPillow
        _, axs = plt.subplots(n_row, n_col, figsize=(12, 12))
        axs = axs.flatten()
        titles = [' Original segmentation', 'Predicted segmentation']
        for title, img, ax in zip(titles, masked_imgs, axs):
            ax.imshow(make_grid(img, 4).permute(1,2,0))
            ax.set_title(title)
        plt.show()
        break
    

dataset_preview(test_data_loader)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
